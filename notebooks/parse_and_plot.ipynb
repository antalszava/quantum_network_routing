# %% [markdown]
# # Running related library modules

# %%
# %run ./lib/plot.py
# %run ./lib/parse_from_log.py

# %%
path = '/home/antal/Documents/eit/thesis/implementation/quantum_routing/notebooks/logs/max_dth_4'
filename = 'global_knowledge__1000__19_03_26__09_45.log'
name_of_approach = 'global'

# %% [markdown]
# # Parsing log specific file

# %%
measures, topologies, results = parse_from_log(path,filename)

# %%
plot_results(results, name_of_approach)
