# %% [markdown]
# # Running related library modules

# %%
# %run ./lib/plot.py
# %run ./lib/parse_from_log.py

# %%
path = '/home/antal/Documents/eit/thesis/implementation/quantum_routing/results/logs'
filename = 'initial_knowledge_1000__19_04_27__12_21.log'
name_of_approach = 'initial'

# %% [markdown]
# # Parsing log specific file

# %%
results = parse_from_log(path,filename)
# Out:
# (['graph0', 'graph1', 'graph2'], ['Average waiting times:', 'Number of available links:', 'Number of available edges:', 'Average distances:'], [([8.213, 134284.8615, 15498798.03166668, 32085206.8205, 56642098.893400006, 60481329.52266665, 80826875.81014279, 100629678.14425, 113971988.60811111, 131681692.52830003, 144697483.6680909, 147559247.10508323, 141661771.07569245, 152744878.40657124, 159279257.94553334, 161106170.2074375, 175997848.68247053, 167848088.92144442, 175669515.4115792, 167764766.63825017, 188829399.97490478, 182724942.63672715, 177252566.9133476, 188634138.26812497, 184126537.4116805, 187474420.31007698, 183919595.77399993, 189802042.4496071, 192877477.92258608, 194878311.50933313, 202339147.42661318, 199976109.574625, 200932685.58490893, 203595403.74032316, 205748777.7470856, 199466604.8782221, 203450268.9145406, 198983919.88965806, 202328723.6367693, 208760057.68647498], [47.787, 44.0905, 40.94333333333332, 37.93375, 35.193799999999975, 32.458833333333295, 29.7451
# ...

# %%
plot_results(results[2], title = name_of_approach, topology_names=['dth=2','dth=4','dth=8'],save_tikz=False)
