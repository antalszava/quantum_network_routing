# %% [markdown]
# # Running related library modules

# %%
# %run ./lib/plot.py
# %run ./lib/parse_from_log.py

# %%
path = '/home/antal/Documents/eit/thesis/implementation/quantum_routing/notebooks/logs/max_dth_8'
filename = 'global_knowledge_power_law_1000__19_04_02__13_41.log'
name_of_approach = 'global'

# %% [markdown]
# # Parsing log specific file

# %%
measures, topologies, results = parse_from_log(path,filename)

# %%
plot_results(results, title = name_of_approach, topology_names=['dth=2','dth=4','dth=8'])
